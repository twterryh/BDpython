# %% [markdown]
# <a href="https://colab.research.google.com/github/twterryh/BDpython/blob/master/0120_02_image_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q mahotas

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# matplotlib 이 한 줄 차지하게 됨

# %%
import mahotas as mh

# %%
image = mh.imread('airport.jpg')

# %%
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.show()
